# %% [markdown]
# Ebben a notebookban vezetem a különböző config-ok teljesítményét, valamint hogy az egyes változtatások (pl. simán baseline modell vagy annak finomhangolt változata) mennyit segítenek.

# %% [markdown]
# Először a nem finomhangolt modellen értékeltem ki a következő paraméterekkel:

# %% [markdown]
# BATCH_SIZE = 8
# EPOCHS = 3
# LR = 2e-5

# %% [markdown]
# <img src="images/image.avif" width="500">

# %% [markdown]
# Majd egy LegalBERT osztállyal finomhangoltam:

# %% [markdown]
# <img src="images/image3.png" width="500">

# %% [markdown]
# Először ilyen eredményeket adott, mivel nem volt elég adaton tanítva:

# %% [markdown]
# BATCH_SIZE = 8
# EPOCHS = 3
# LR = 2e-5

# %% [markdown]
# <img src="images/image2.png" width="500">

# %% [markdown]
# Az alapmodellt is lecseréltem, mivel az multi-language modell volt, a SZTAKI-nak létezik olyan BERT modellje, amely magyar szövegen lett tanítva.

# %% [markdown]
# Itt már az összes adat felén tanítottam (többen nem tudtam, mivel ha az összeset felhasználom, a tanítás akár 5-6 óra is lett volna).

# %% [markdown]
# MODEL_NAME = "SZTAKI-HLT/hubert-base-cc"
# MAX_LENGTH = 256
# BATCH_SIZE = 16
# EPOCHS = 10
# LR = 2e-4

# %% [markdown]
# <img src="images/image6.png" width="500">

# %% [markdown]
# Confusion matrix:

# %% [markdown]
# <img src="images/image5.png" width="1000">
